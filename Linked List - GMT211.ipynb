# %%
#Assume the first element of the linked list is 0.
#Assume the indices of a linked list start with 0.
#Create a linked list with the first N integers 
#Write a function to print all elements of a linked list.

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

    def print_list(self):
        current = self.head
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

def create_linked_list_with_first_n_integers(N):
    if N < 1:
        return None

    linked_list = LinkedList()
    for i in range(N):
        linked_list.append(i)
    
    return linked_list

N = 10  
linked_list = create_linked_list_with_first_n_integers(N)

if linked_list:
    print("Linked List with the first", N, "integers:")
    linked_list.print_list()
else:
    print("N should be at least 1 to create a linked list.")

# %%
# Access the value at a user provided index x.


def get_value_at_index(linked_list, x):
    current = linked_list.head
    index = 0
    while current and index < x:
        current = current.next
        index += 1
    if current is None:
        return None
    return current.data

N = 10 
linked_list = create_linked_list_with_first_n_integers(N) 

x = 3 
value_at_x = get_value_at_index(linked_list, x)

if value_at_x is not None:
    print(f"Index {x}'teki değer: {value_at_x}")
else:
    print(f"İndeks {x} geçerli değil.")

# %%
# Remove the input value node from the linked list.

def remove_value(linked_list, value_to_remove):
    current = linked_list.head
    if current and current.data == value_to_remove:
        linked_list.head = current.next
        return

    while current:
        if current.next and current.next.data == value_to_remove:
            current.next = current.next.next
            return
        current = current.next

# %%
#Try removing from an empty linked list.

def remove_value(linked_list, value_to_remove):
    if linked_list.head is None:
        return 

    current = linked_list.head
    if current.data == value_to_remove:
        linked_list.head = current.next
        return

    while current.next:
        if current.next.data == value_to_remove:
            current.next = current.next.next
            return
        current = current.next
